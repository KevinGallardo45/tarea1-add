# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Para cargar los datos es primero necesario utilizar el parametro on_bad_lines y utilizar skip ya que el dataframe en si trae texto dentro de si lo cual hace que leerlo solo llamando al archivo sea imposible
#
# Por ultimo, utilizar el separador ; y setear el indice con los valores de la columna Día

# %%
dolar_2019 = pd.read_csv('/home/pato/Documents/GitHub/tarea1-add/data/raw/dolar2019_sii.csv',
                        on_bad_lines='skip', sep=';')

# %%
dolar_2019.set_index('Día', inplace=True)

# %%
años = []
for i in range (0,32):
    años.append(2019)

dolar_2019['year'] = np.asarray(años, dtype = 'int64')
dolar_2019 = dolar_2019.replace(',', '.', regex=True)
dolar_2019 = dolar_2019.astype(dtype='float64')

# %%
dolar_2019.head()
# Out:
#         Ene     Feb     Mar     Abr     May     Jun     Jul     Ago     Sep  \
# Día
# 1       NaN  657.81  651.79  678.53     NaN     NaN  679.15  700.82     NaN
# 2    694.77     NaN     NaN  672.56  678.71     NaN  677.62  704.88  720.20
# 3    697.09     NaN     NaN  670.05  683.31  709.80  681.30     NaN  724.72
# 4    697.64  655.39  656.57  667.55     NaN  704.59  680.48     NaN  725.69
# 5       NaN  653.80  659.07  666.32     NaN  696.78  677.64  711.13  723.30
#
#         Oct     Nov     Dic    year
# Día
# 1    728.21     NaN     NaN  2019.0
# 2    729.38     NaN  812.13  2019.0
# 3    727.80     NaN  804.29  2019.0
# 4    719.53  735.05  802.44  2019.0
# 5       NaN  736.66  796.75  2019.0

# %%
dolar_2019.to_csv('/home/pato/Documents/GitHub/tarea1-add/data/interim/d2019.csv', sep=',')

# %% [markdown]
# Este otro dataframe tiene un formato parecido, solo que a diferencia del otro este no trae las columnas de los meses y la de dia, y por ultimo el separador de estos datos ya no es el ; si no que el |.
#
# Por lo tanto, primero hay que pasarle las columnas, y el nuevo separador. Por ultimo, setear el indice a los valores de la columna Día

# %%
columnas = ['Día', 'Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Sep',
       'Oct', 'Nov', 'Dic']

dolar_2020_txt = pd.read_table('/home/pato/Documents/GitHub/tarea1-add/data/raw/dolar_2020_sii.txt',
                               sep='|', header=None)

# %%
dolar_2020_txt.columns = columnas
dolar_2020_txt.set_index('Día', inplace=True)

# %%
años = []
for i in range (0,32):
    años.append(2020)

dolar_2020_txt['year'] = np.asarray(años, dtype = 'int64')
dolar_2020_txt = dolar_2020_txt.replace(',','.', regex=True)
dolar_2020_txt = dolar_2020_txt.astype(dtype='float64')

# %%
dolar_2020_txt.head()
# Out:
#         Ene     Feb     Mar     Abr     May     Jun     Jul     Ago     Sep  \
# Día
# 1       NaN     NaN     NaN  852.03     NaN  806.32  821.23     NaN  776.46
# 2    748.74     NaN  818.32  863.81     NaN  796.46  816.29     NaN  770.59
# 3    754.16  799.11  817.45  861.89     NaN  782.86  803.98  757.06  771.45
# 4       NaN  790.92  809.81     NaN  837.92  769.13     NaN  761.34  773.71
# 5       NaN  781.78  812.19     NaN  838.74  775.58     NaN  767.98     NaN
#
#         Oct     Nov     Dic    year
# Día
# 1    788.15     NaN  767.29  2020.0
# 2    785.04  771.92  760.16  2020.0
# 3       NaN  769.17  755.34  2020.0
# 4       NaN  758.53  752.03  2020.0
# 5    790.81  757.16     NaN  2020.0

# %%
dolar_2020_txt.to_csv(r'/home/pato/Documents/GitHub/tarea1-add/data/interim/d2020.txt', sep=' ')

# %%
dolar_2020_regex = pd.read_table('/home/pato/Documents/GitHub/tarea1-add/data/raw/dolar_2020_sii_AA.dat', 
                                 header=None)

# %%
dolar_2020_regex.head()
# Out:
#                                                    0
# 0  1XAXXAXXAXXAX852,03XAXXAX806,32XAX821,23XAXXAX...
# 1  2XBX748,74XBXXBX818,32XBX863,81XBXXBX796,46XBX...
# 2  3XBX754,16XZX799,11XZX817,45XZX861,89XZXXZX782...
# 3  4XZXXtX790,92XtX809,81XtXXtX837,92XtX769,13XtX...
# 4  5XtXXtX781,78XtX812,19XtXXtX838,74XtX775,58XtX...

# %%
promedio = str(dolar_2020_regex.values[31]).replace('PromedioXYX', '')
promedio = promedio.replace('[', '').replace(']', '').replace("'", "")

# %%
import re
list_promedio = []

match_promedio = re.split('[a-zA-Zá-ý]{3}', promedio)
match_promedio.insert(0, 'Promedio')

# %%
new_match = []
for i in range(0,31):
    match = re.split('[a-zA-Zá-ý]{3}', dolar_2020_regex.values[i,0])
    new_match.append(match)

new_match.append(match_promedio)

# %%
dolar_2020_regex_new = pd.DataFrame(new_match, columns=columnas)

# %%
dolar_2020_regex_new.head()
# Out:
#   Día     Ene     Feb     Mar     Abr     May     Jun     Jul     Ago     Sep  \
# 0   1                          852,03          806,32  821,23          776,46
# 1   2  748,74          818,32  863,81          796,46  816,29          770,59
# 2   3  754,16  799,11  817,45  861,89          782,86  803,98  757,06  771,45
# 3   4          790,92  809,81          837,92  769,13          761,34  773,71
# 4   5          781,78  812,19          838,74  775,58          767,98
#
#       Oct     Nov     Dic
# 0  788,15          767,29
# 1  785,04  771,92  760,16
# 2          769,17  755,34
# 3          758,53  752,03
# 4  790,81  757,16

# %%
dolar_2020_regex_new.set_index('Día', inplace=True)

# %%
años = []
for i in range (0,32):
    años.append(2020)

dolar_2020_regex_new['year'] = np.asarray(años, dtype = 'int64')
dolar_2020_regex_new = dolar_2020_regex_new.replace(',','.', regex=True)
dolar_2020_regex_new = dolar_2020_regex_new.astype(dtype='float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_37642/3067062540.py in <module>
#       5 dolar_2020_regex_new['year'] = np.asarray(años, dtype = 'int64')
#       6 dolar_2020_regex_new = dolar_2020_regex_new.replace(',','.', regex=True)
# ----> 7 dolar_2020_regex_new = dolar_2020_regex_new.astype(dtype='float')
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1093     if arr.ndim > 1:
#    1094         flat = arr.ravel()
# -> 1095         result = astype_nansafe(flat, dtype, copy=copy, skipna=skipna)
#    1096         # error: Item "ExtensionArray" of "Union[ExtensionArray, ndarray]" has no
#    1097         # attribute "reshape"
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1199     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1200         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1201         return arr.astype(dtype, copy=True)
#    1202
#    1203     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# El nuevo dataframe del dolar_2020_regex es casi igual al anterior, lo unico es que los valores vienen en blanco en vez de valores NaN, pero al reemplazar los valores vacios con NaN ambos dataframes se ven exactamente iguales

# %%
dolar_2020_regex_new = dolar_2020_regex_new.replace('', np.nan)
dolar_2020_regex_new.head()

# %%
dolar_2020_regex_new.to_csv('/home/pato/Documents/GitHub/tarea1-add/data/interim/dolar_2020_excel.csv', sep=';')

# %%
df_concat_1 = pd.concat([dolar_2019, dolar_2020_txt], axis=1)

# %%
df_concat_1
# Out:
#              Ene     Feb     Mar     Abr     May     Jun     Jul     Ago  \
# 11        714.77  720.61  ...     NaN  827.65  767.93     NaN  796.58  764.99
# 12        714.39     NaN  ...     NaN  826.05  784.65     NaN  793.61     NaN
# 13        711.29     NaN  ...  839.49  821.88     NaN  790.82  792.69     NaN
# 14           NaN  712.98  ...  844.57  820.38     NaN  788.22  793.32  768.34
# 15           NaN  712.04  ...  848.63  822.93  790.73  787.87     NaN  767.01
# 16        707.07  715.48  ...  859.31     NaN  796.87     NaN     NaN  760.01
# 17        709.81  718.69  ...  852.52     NaN  779.10  787.50  796.73  761.54
# 18           NaN  713.23  ...     NaN  823.86  798.53     NaN  803.40     NaN
# 19           NaN     NaN  ...     NaN  820.65  812.19     NaN  796.23     NaN
# 20           NaN     NaN  ...  849.45  819.08     NaN  787.26  784.25     NaN
# 21           NaN  709.71  ...  856.23     NaN     NaN  786.04  785.84  764.34
# 22           NaN  723.52  ...  862.06  806.17  817.33  777.66     NaN  772.83
# 23        715.24  726.24  ...  856.51     NaN  816.02  769.06     NaN  773.40
# 24        722.17  726.15  ...  858.87     NaN  817.90  767.17  790.88  781.44
# 25        721.92  723.43  ...     NaN  805.75  820.68     NaN  786.17  788.02
# 26        727.08     NaN  ...     NaN  803.74  813.25     NaN  784.44     NaN
# 27        726.17     NaN  ...  859.95  802.10     NaN  768.63  786.91     NaN
# 28           NaN  725.87  ...  856.76  816.47     NaN  768.81  784.27  787.15
# 29           NaN  724.37  ...  850.41  812.74     NaN  767.82     NaN  784.19
# 30        725.68  726.34  ...  836.62     NaN  816.36  759.18     NaN  784.46
# 31           NaN     NaN  ...     NaN     NaN     NaN  754.45  779.92     NaN
# Promedio  718.44  721.03  ...  853.38  821.81  793.72  784.73  784.66  773.40
#
#              Oct     Nov     Dic    year
# Día
# 1         788.15     NaN  767.29  2020.0
# 2         785.04  771.92  760.16  2020.0
# 3            NaN  769.17  755.34  2020.0
# 4            NaN  758.53  752.03  2020.0
# 5         790.81  757.16     NaN  2020.0
# 6         794.34  752.01     NaN  2020.0
# 7         797.35     NaN  747.61  2020.0
# 8         795.05     NaN     NaN  2020.0
# 9         797.25  759.25  744.82  2020.0
# 10           NaN  753.75  739.45  2020.0
# 11           NaN  760.90  738.17  2020.0
# 12           NaN  757.42     NaN  2020.0
# 13        796.05  757.43     NaN  2020.0
# 14        797.66     NaN  733.55  2020.0
# 15        798.56     NaN  731.58  2020.0
# 16        801.91  766.70  734.23  2020.0
# 17           NaN  767.86  735.09  2020.0
# 18           NaN  767.05  723.44  2020.0
# 19        795.68  758.10     NaN  2020.0
# 20        788.27  758.62     NaN  2020.0
# 21        786.66     NaN  723.85  2020.0
# 22        784.07     NaN  730.70  2020.0
# 23        781.41  761.55  728.96  2020.0
# 24           NaN  765.96  716.25  2020.0
# 25           NaN  772.83     NaN  2020.0
# 26        777.72  771.68     NaN  2020.0
# 27        779.57  766.00     NaN  2020.0
# 28        772.05     NaN  710.26  2020.0
# 29        775.56     NaN  710.64  2020.0
# 30        770.45  766.69  711.24  2020.0
# 31           NaN     NaN     NaN  2020.0
# Promedio  788.27  762.88  734.73  2020.0
#
# [32 rows x 26 columns]

# %%
df_concat_0 = pd.concat([dolar_2019, dolar_2020_txt], axis=0)

# %%
df_concat_0
# Out:
#              Ene     Feb     Mar     Abr     May     Jun     Jul     Ago  \
# Día
# 1            NaN  657.81  651.79  678.53     NaN     NaN  679.15  700.82
# 2         694.77     NaN     NaN  672.56  678.71     NaN  677.62  704.88
# 3         697.09     NaN     NaN  670.05  683.31  709.80  681.30     NaN
# 4         697.64  655.39  656.57  667.55     NaN  704.59  680.48     NaN
# 5            NaN  653.80  659.07  666.32     NaN  696.78  677.64  711.13
# ...          ...     ...     ...     ...     ...     ...     ...     ...
# 28        787.86  816.26     NaN  856.76  816.47     NaN  768.81  784.27
# 29        788.13     NaN     NaN  850.41  812.74     NaN  767.82     NaN
# 30        788.18     NaN  835.23  836.62     NaN  816.36  759.18     NaN
# 31        797.96     NaN  846.30     NaN     NaN     NaN  754.45  779.92
# Promedio  772.65  796.38  839.38  853.38  821.81  793.72  784.73  784.66
#
#              Sep     Oct     Nov     Dic    year
# Día
# 1            NaN  728.21     NaN     NaN  2019.0
# 2         720.20  729.38     NaN  812.13  2019.0
# 3         724.72  727.80     NaN  804.29  2019.0
# 4         725.69  719.53  735.05  802.44  2019.0
# 5         723.30     NaN  736.66  796.75  2019.0
# ...          ...     ...     ...     ...     ...
# 28        787.15  772.05     NaN  710.26  2020.0
# 29        784.19  775.56     NaN  710.64  2020.0
# 30        784.46  770.45  766.69  711.24  2020.0
# 31           NaN     NaN     NaN     NaN  2020.0
# Promedio  773.40  788.27  762.88  734.73  2020.0
#
# [64 rows x 13 columns]

# %%
df_concat_0.info
# Out:
# <bound method DataFrame.info of              Ene     Feb     Mar     Abr     May     Jun     Jul     Ago  \
# Día
# 1            NaN  657.81  651.79  678.53     NaN     NaN  679.15  700.82
# 2         694.77     NaN     NaN  672.56  678.71     NaN  677.62  704.88
# 3         697.09     NaN     NaN  670.05  683.31  709.80  681.30     NaN
# 4         697.64  655.39  656.57  667.55     NaN  704.59  680.48     NaN
# 5            NaN  653.80  659.07  666.32     NaN  696.78  677.64  711.13
# ...          ...     ...     ...     ...     ...     ...     ...     ...
# 28        787.86  816.26     NaN  856.76  816.47     NaN  768.81  784.27
# 29        788.13     NaN     NaN  850.41  812.74     NaN  767.82     NaN
# 30        788.18     NaN  835.23  836.62     NaN  816.36  759.18     NaN
# 31        797.96     NaN  846.30     NaN     NaN     NaN  754.45  779.92
# Promedio  772.65  796.38  839.38  853.38  821.81  793.72  784.73  784.66
#
#              Sep     Oct     Nov     Dic    year
# Día
# 1            NaN  728.21     NaN     NaN  2019.0
# 2         720.20  729.38     NaN  812.13  2019.0
# 3         724.72  727.80     NaN  804.29  2019.0
# 4         725.69  719.53  735.05  802.44  2019.0
# 5         723.30     NaN  736.66  796.75  2019.0
# ...          ...     ...     ...     ...     ...
# 28        787.15  772.05     NaN  710.26  2020.0
# 29        784.19  775.56     NaN  710.64  2020.0
# 30        784.46  770.45  766.69  711.24  2020.0
# 31           NaN     NaN     NaN     NaN  2020.0
# Promedio  773.40  788.27  762.88  734.73  2020.0
#
# [64 rows x 13 columns]>

# %% [markdown]
# El problema que se presenta en df_concat_1 es que toma el año 2019 en medio de la planilla y el del 2020 al final, mientras que con el df_concat_
